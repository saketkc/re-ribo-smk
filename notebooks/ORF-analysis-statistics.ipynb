# %%
# %pylab inline
import pandas as pd
import seaborn as sns
sns.set_style('white')
sns.set_context('paper', font_scale=2)
import pyfaidx
from Bio.Seq import Seq
from Bio.Alphabet import generic_dna

fasta = pyfaidx.Fasta('/home/cmb-panasas2/skchoudh/genomes/hg38/fasta/hg38.fa')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from collections import defaultdict
import gzip
import pandas as pd
import re


GTF_HEADER  = ['seqname', 'source', 'feature', 'start', 'end', 'score',
               'strand', 'frame']
R_SEMICOLON = re.compile(r'\s*;\s*')
R_COMMA     = re.compile(r'\s*,\s*')
R_KEYVALUE  = re.compile(r'(\s+|\s*=\s*)')


def dataframe(filename):
    """Open an optionally gzipped GTF file and return a pandas.DataFrame.
    """
    # Each column is a list stored as a value in this dict.
    result = defaultdict(list)

    for i, line in enumerate(lines(filename)):
        for key in line.keys():
            # This key has not been seen yet, so set it to None for all
            # previous lines.
            if key not in result:
                result[key] = [None] * i

        # Ensure this row has some value for each column.
        for key in result.keys():
            result[key].append(line.get(key, None))

    return pd.DataFrame(result)


def lines(filename):
    """Open an optionally gzipped GTF file and generate a dict for each line.
    """
    fn_open = gzip.open if filename.endswith('.gz') else open

    with fn_open(filename) as fh:
        for line in fh:
            if line.startswith('#'):
                continue
            else:
                yield parse(line)


def parse(line):
    """Parse a single GTF line and return a dict.
    """
    result = {}

    fields = line.rstrip().split('\t')

    for i, col in enumerate(GTF_HEADER):
        result[col] = _get_value(fields[i])

    # INFO field consists of "key1=value;key2=value;...".
    infos = [x for x in re.split(R_SEMICOLON, fields[8]) if x.strip()]

    for i, info in enumerate(infos, 1):
        # It should be key="value".
        try:
            key, _, value = re.split(R_KEYVALUE, info, 1)
        # But sometimes it is just "value".
        except ValueError:
            key = 'INFO{}'.format(i)
            value = info
        # Ignore the field if there is no value.
        if value:
            result[key] = _get_value(value)

    return result


def _get_value(value):
    if not value:
        return None

    # Strip double and single quotes.
    value = value.strip('"\'')

    # Return a list if the value has a comma.
    if ',' in value:
        value = re.split(R_COMMA, value)
    # These values are equivalent to None.
    elif value in ['', '.', 'NA']:
        return None

    return value

def get_seq(row):
    chrom = row['seqname']
    start = row['start']
    end = row['end']
    strand = row['strand']
    
    if strand == '+':
        return fasta.get_seq(chrom, start, end)
    else:
        seq = fasta.get_seq(chrom, start, end)
        return str(Seq(seq, generic_dna).reverse_complement())

# %%
gtf = dataframe('/home/cmb-panasas2/skchoudh/genomes/hg38/annotation/gencode.v25.annotation.gtf')
gtf['start'] = gtf['start'].astype(int)
gtf['end'] = gtf['end'].astype(int)

# %%
gtf.head()
# Out:
#   ccdsid    end            exon_id exon_number     feature frame  \
# 0   None  14409               None        None        gene  None
# 1   None  14409               None        None  transcript  None
# 2   None  12227  ENSE00002234944.1           1        exon  None
# 3   None  12721  ENSE00003582793.1           2        exon  None
# 4   None  14409  ENSE00002312635.1           3        exon  None
#
#              gene_id gene_name gene_status  \
# 0  ENSG00000223972.5   DDX11L1       KNOWN
# 1  ENSG00000223972.5   DDX11L1       KNOWN
# 2  ENSG00000223972.5   DDX11L1       KNOWN
# 3  ENSG00000223972.5   DDX11L1       KNOWN
# 4  ENSG00000223972.5   DDX11L1       KNOWN
#
#                             gene_type  ... seqname  source  start strand  \
# 0  transcribed_unprocessed_pseudogene  ...    chr1  HAVANA  11869      +
# 1  transcribed_unprocessed_pseudogene  ...    chr1  HAVANA  11869      +
# 2  transcribed_unprocessed_pseudogene  ...    chr1  HAVANA  11869      +
# 3  transcribed_unprocessed_pseudogene  ...    chr1  HAVANA  12613      +
# 4  transcribed_unprocessed_pseudogene  ...    chr1  HAVANA  13221      +
#
#      tag      transcript_id transcript_name transcript_status  \
# 0   None               None            None              None
# 1  basic  ENST00000456328.2     DDX11L1-002             KNOWN
# 2  basic  ENST00000456328.2     DDX11L1-002             KNOWN
# 3  basic  ENST00000456328.2     DDX11L1-002             KNOWN
# 4  basic  ENST00000456328.2     DDX11L1-002             KNOWN
#
#    transcript_support_level       transcript_type
# 0                      None                  None
# 1                         1  processed_transcript
# 2                         1  processed_transcript
# 3                         1  processed_transcript
# 4                         1  processed_transcript
#
# [5 rows x 26 columns]

# %%
start_codons = gtf[gtf.feature=='start_codon']
start_codons.head()
# Out:
#           ccdsid     end            exon_id exon_number      feature frame  \
# 56   CCDS30547.1   69093  ENSE00002319515.1           1  start_codon     0
# 131         None  182711  ENSE00003759020.1           1  start_codon     0
# 143         None  195411  ENSE00003758618.1           1  start_codon     0
# 167         None  195411  ENSE00003755778.1           1  start_codon     0
# 193         None  200086  ENSE00003757911.1           1  start_codon     0
#
#                gene_id   gene_name gene_status       gene_type  ... seqname  \
# 56   ENSG00000186092.4       OR4F5       KNOWN  protein_coding  ...    chr1
# 131  ENSG00000279928.1  FO538757.2       KNOWN  protein_coding  ...    chr1
# 143  ENSG00000279457.3  FO538757.1       KNOWN  protein_coding  ...    chr1
# 167  ENSG00000279457.3  FO538757.1       KNOWN  protein_coding  ...    chr1
# 193  ENSG00000279457.3  FO538757.1       KNOWN  protein_coding  ...    chr1
#
#       source   start strand                   tag      transcript_id  \
# 56    HAVANA   69091      +                  CCDS  ENST00000335137.3
# 131  ENSEMBL  182709      +    appris_principal_1  ENST00000624431.1
# 143  ENSEMBL  195409      -  appris_alternative_2  ENST00000623834.3
# 167  ENSEMBL  195409      -    appris_principal_5  ENST00000623083.3
# 193  ENSEMBL  200084      -  appris_alternative_2  ENST00000624735.1
#
#     transcript_name transcript_status  transcript_support_level  \
# 56        OR4F5-001             KNOWN                      None
# 131  FO538757.2-201             KNOWN                         1
# 143  FO538757.1-201             KNOWN                         5
# 167  FO538757.1-202             KNOWN                         5
# 193  FO538757.1-203             KNOWN                         5
#
#     transcript_type
# 56   protein_coding
# 131  protein_coding
# 143  protein_coding
# 167  protein_coding
# 193  protein_coding
#
# [5 rows x 26 columns]

# %%
start_codons['length'] = start_codons['end'].astype(int)-start_codons['start'].astype(int)+1
start_codons['length'].describe()
# Out:
# /auto/cmb-panasas2/skchoudh/software_frozen/anaconda27/envs/riboraptor/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# count    82648.000000
# mean         2.990744
# std          0.123860
# min          1.000000
# 25%          3.000000
# 50%          3.000000
# 75%          3.000000
# max          3.000000
# Name: length, dtype: float64

# %%
start_codons[start_codons['length']==1]
# Out:
#               ccdsid        end            exon_id exon_number      feature  \
# 13738           None    6463072  ENSE00003657231.1           5  start_codon
# 15068       CCDS88.1    7773442  ENSE00001474297.1           2  start_codon
# 2417553  CCDS74791.1   36057384  ENSE00001536969.1           3  start_codon
# 2417629         None   36057384  ENSE00001536969.1           3  start_codon
# 2417647         None   36057384  ENSE00001536969.1           3  start_codon
# 2440629         None   20122264  ENSE00003563009.1           3  start_codon
# 2440639         None   20122264  ENSE00003563009.1           3  start_codon
# 2440649         None   20122264  ENSE00003563009.1           3  start_codon
# 2440663         None   20122264  ENSE00003563009.1           3  start_codon
# 2481246  CCDS58808.1   44069162  ENSE00001550108.1           1  start_codon
# 2551060         None  131078754  ENSE00001747004.2           1  start_codon
#
#         frame             gene_id gene_name gene_status       gene_type  ...  \
# 13738       0   ENSG00000215788.9  TNFRSF25       KNOWN  protein_coding  ...
# 15068       1  ENSG00000049245.12     VAMP3       KNOWN  protein_coding  ...
# 34452       1   ENSG00000227868.5  C1orf234       KNOWN  protein_coding  ...
# 55796       1  ENSG00000054116.11   TRAPPC3       KNOWN  protein_coding  ...
# 55831       1  ENSG00000054116.11   TRAPPC3       KNOWN  protein_coding  ...
# 55847       1  ENSG00000054116.11   TRAPPC3       KNOWN  protein_coding  ...
# 75736       1  ENSG00000123472.12    ATPAF1       KNOWN  protein_coding  ...
# 75796       1  ENSG00000123472.12    ATPAF1       KNOWN  protein_coding  ...
# 94090       0  ENSG00000033122.18     LRRC7       KNOWN  protein_coding  ...
# 94149       1  ENSG00000033122.18     LRRC7       KNOWN  protein_coding  ...
# 149256      1  ENSG00000163239.12    TDRD10       KNOWN  protein_coding  ...
# 149288      1  ENSG00000163239.12    TDRD10       KNOWN  protein_coding  ...
# 166821      1  ENSG00000158793.13      NIT1       KNOWN  protein_coding  ...
# 166899      1  ENSG00000158793.13      NIT1       KNOWN  protein_coding  ...
# 193781      0  ENSG00000159176.13     CSRP1       KNOWN  protein_coding  ...
# 209200      0  ENSG00000082482.13     KCNK2       KNOWN  protein_coding  ...
# 209235      0  ENSG00000082482.13     KCNK2       KNOWN  protein_coding  ...
# 232164      0  ENSG00000035115.21    SH3YL1       KNOWN  protein_coding  ...
# 232273      0  ENSG00000035115.21    SH3YL1       KNOWN  protein_coding  ...
# 232301      0  ENSG00000035115.21    SH3YL1       KNOWN  protein_coding  ...
# 232492      0  ENSG00000035115.21    SH3YL1       KNOWN  protein_coding  ...
# 232513      0  ENSG00000035115.21    SH3YL1       KNOWN  protein_coding  ...
# 256406      0  ENSG00000091106.18     NLRC4       KNOWN  protein_coding  ...
# 256430      0  ENSG00000091106.18     NLRC4       KNOWN  protein_coding  ...
# 256454      0  ENSG00000091106.18     NLRC4       KNOWN  protein_coding  ...
# 256477      0  ENSG00000091106.18     NLRC4       KNOWN  protein_coding  ...
# 271271      1  ENSG00000115310.17      RTN4       KNOWN  protein_coding  ...
# 317159      1  ENSG00000125611.15    CHCHD5       KNOWN  protein_coding  ...
# 317173      1  ENSG00000125611.15    CHCHD5       KNOWN  protein_coding  ...
# 317185      1  ENSG00000125611.15    CHCHD5       KNOWN  protein_coding  ...
# ...       ...                 ...       ...         ...             ...  ...
# 2280834     0  ENSG00000068903.19     SIRT2       KNOWN  protein_coding  ...
# 2280888     0  ENSG00000068903.19     SIRT2       KNOWN  protein_coding  ...
# 2280908     0  ENSG00000068903.19     SIRT2       KNOWN  protein_coding  ...
# 2280940     0  ENSG00000068903.19     SIRT2       KNOWN  protein_coding  ...
# 2280960     0  ENSG00000068903.19     SIRT2       KNOWN  protein_coding  ...
# 2280978     0  ENSG00000068903.19     SIRT2       KNOWN  protein_coding  ...
# 2280992     0  ENSG00000068903.19     SIRT2       KNOWN  protein_coding  ...
# 2282176     0  ENSG00000130755.12      GMFG       KNOWN  protein_coding  ...
# 2282211     0  ENSG00000130755.12      GMFG       KNOWN  protein_coding  ...
# 2303526     1  ENSG00000125743.10    SNRPD2       KNOWN  protein_coding  ...
# 2303587     1  ENSG00000125743.10    SNRPD2       KNOWN  protein_coding  ...
# 2303600     1  ENSG00000125743.10    SNRPD2       KNOWN  protein_coding  ...
# 2307505     1  ENSG00000142230.11      SAE1       KNOWN  protein_coding  ...
# 2315946     0   ENSG00000161609.9   CCDC155       KNOWN  protein_coding  ...
# 2344263     1  ENSG00000105146.12     AURKC       KNOWN  protein_coding  ...
# 2344283     0  ENSG00000105146.12     AURKC       KNOWN  protein_coding  ...
# 2344358     1  ENSG00000105146.12     AURKC       KNOWN  protein_coding  ...
# 2344376     1  ENSG00000105146.12     AURKC       KNOWN  protein_coding  ...
# 2360212     1  ENSG00000125864.12     BFSP1       KNOWN  protein_coding  ...
# 2417441     0  ENSG00000185917.13     SETD4       KNOWN  protein_coding  ...
# 2417512     0  ENSG00000185917.13     SETD4       KNOWN  protein_coding  ...
# 2417553     0  ENSG00000185917.13     SETD4       KNOWN  protein_coding  ...
# 2417629     0  ENSG00000185917.13     SETD4       KNOWN  protein_coding  ...
# 2417647     0  ENSG00000185917.13     SETD4       KNOWN  protein_coding  ...
# 2440629     1  ENSG00000099901.16    RANBP1       KNOWN  protein_coding  ...
# 2440639     1  ENSG00000099901.16    RANBP1       KNOWN  protein_coding  ...
# 2440649     1  ENSG00000099901.16    RANBP1       KNOWN  protein_coding  ...
# 2440663     1  ENSG00000099901.16    RANBP1       KNOWN  protein_coding  ...
# 2481246     0  ENSG00000188677.14     PARVB       KNOWN  protein_coding  ...
# 2551060     0  ENSG00000147256.10  ARHGAP36       KNOWN  protein_coding  ...
#
#           source      start strand                   tag       transcript_id  \
# 13738     HAVANA    6463072      -            cds_end_NF   ENST00000481401.5
# 15068     HAVANA    7773442      +                  CCDS  ENST00000054666.10
# 34452     HAVANA   23014045      -                  CCDS   ENST00000566855.3
# 55796    ENSEMBL   36139819      -                  CCDS   ENST00000617904.4
# 55831     HAVANA   36139819      -                  CCDS   ENST00000373163.5
# 55847     HAVANA   36139819      -                  CCDS   ENST00000373162.5
# 75736     HAVANA   46665364      -                  None   ENST00000529214.5
# 75796     HAVANA   46665364      -                  CCDS   ENST00000532925.5
# 94090     HAVANA   69716218      +  appris_alternative_2   ENST00000310961.9
# 94149     HAVANA   69678381      +                 basic   ENST00000370958.5
# 149256    HAVANA  154507241      +                  CCDS   ENST00000368482.8
# 149288    HAVANA  154507241      +                  CCDS   ENST00000368480.3
# 166821    HAVANA  161118786      +                  CCDS   ENST00000368009.6
# 166899    HAVANA  161118786      +                  CCDS   ENST00000368008.5
# 15068         VAMP3-001             KNOWN                        1
# 34452      C1orf234-001             KNOWN                        2
# 55796       TRAPPC3-203             KNOWN                        2
# 55831       TRAPPC3-005             KNOWN                        3
# 55847       TRAPPC3-004             KNOWN                        2
# 75736        ATPAF1-009             KNOWN                        2
# 75796        ATPAF1-008             KNOWN                        2
# 94090         LRRC7-002             KNOWN                        5
# 94149         LRRC7-003             KNOWN                        1
# 149256       TDRD10-005             KNOWN                        1
# 149288       TDRD10-002             KNOWN                        2
# 166821         NIT1-001             KNOWN                        1
# 166899         NIT1-002             KNOWN                        1
# 193781        CSRP1-012             KNOWN                        2
# 209200        KCNK2-002             KNOWN                        1
# 209235        KCNK2-010             KNOWN                        5
# 232164       SH3YL1-002             KNOWN                        1
# 232273       SH3YL1-003             KNOWN                        5
# 232301       SH3YL1-001             KNOWN                        1
# 232492       SH3YL1-004             KNOWN                        1
# 232513       SH3YL1-016             KNOWN                        3
# 256406        NLRC4-002             KNOWN                        1
# 256430        NLRC4-004             KNOWN                        1
# 256454        NLRC4-003             KNOWN                        1
# 256477        NLRC4-001             KNOWN                        5
# 271271         RTN4-201             KNOWN                        5
# 317159       CHCHD5-001             KNOWN                        1
# 317173       CHCHD5-002             KNOWN                        2
# 317185       CHCHD5-003             KNOWN                        2
# ...                 ...               ...                      ...
# 2280834       SIRT2-010             KNOWN                        5
# 2280888       SIRT2-005             KNOWN                        2
# 2280908       SIRT2-016             KNOWN                        2
# 2280940       SIRT2-011             KNOWN                        4
# 2280960       SIRT2-012             KNOWN                        4
# 2280978       SIRT2-007             KNOWN                        4
# 2280992       SIRT2-006             KNOWN                        4
# 2282176        GMFG-012             KNOWN                        5
# 2282211        GMFG-005             KNOWN                        5
# 2303526      SNRPD2-001             KNOWN                        1
# 2303587      SNRPD2-002             KNOWN                        3
# 2303600      SNRPD2-008             KNOWN                        3
# 2307505        SAE1-010             KNOWN                        5
# 2315946     CCDC155-013             KNOWN                        5
# 2344263       AURKC-201             KNOWN                        5
# 2344283       AURKC-002             KNOWN                        1
# 2344358       AURKC-004             KNOWN                        1
# 2344376       AURKC-006             KNOWN                        3
# 2360212       BFSP1-002             KNOWN                        1
# 2417441       SETD4-003             KNOWN                        1
# 2417512       SETD4-004             KNOWN                        1
# 2417553       SETD4-007             KNOWN                        1
# 2417629       SETD4-009             KNOWN                        3
# 2417647       SETD4-014             KNOWN                        4
# 2440629      RANBP1-006             KNOWN                        5
# 2440639      RANBP1-007             KNOWN                        3
# 2440649      RANBP1-008             KNOWN                        3
# 2440663      RANBP1-009             KNOWN                        3
# 2481246       PARVB-003             KNOWN                        1
# 2551060    ARHGAP36-004             KNOWN                        1
#
#                  transcript_type length
# 13738             protein_coding      1
# 15068             protein_coding      1
# 34452             protein_coding      1
# 55796             protein_coding      1
# 55831             protein_coding      1
# 55847             protein_coding      1
# 75736    nonsense_mediated_decay      1
# 75796             protein_coding      1
# 94090             protein_coding      1
# 94149             protein_coding      1
# 149256            protein_coding      1
# 149288            protein_coding      1
# 166821            protein_coding      1
# 166899            protein_coding      1
# 193781            protein_coding      1
# 209200            protein_coding      1
# 209235   nonsense_mediated_decay      1
# 232164            protein_coding      1
# 232273            protein_coding      1
# 232301            protein_coding      1
# 232492            protein_coding      1
# 232513            protein_coding      1
# 256406            protein_coding      1
# 256430            protein_coding      1
# 256454            protein_coding      1
# 256477            protein_coding      1
# 271271            protein_coding      1
# 317159            protein_coding      1
# 317173   nonsense_mediated_decay      1
# 317185            protein_coding      1
# ...                          ...    ...
# 2280834  nonsense_mediated_decay      1
# 2280888           protein_coding      1
# 2280908           protein_coding      1
# 2280940  nonsense_mediated_decay      1
# 2280960  nonsense_mediated_decay      1
# 2280978           protein_coding      1
# 2280992           protein_coding      1
# 2282176           protein_coding      1
# 2282211           protein_coding      1
# 2303526           protein_coding      1
# 2303587           protein_coding      1
# 2303600           protein_coding      1
# 2307505           protein_coding      1
# 2315946           protein_coding      1
# 2344263           protein_coding      1
# 2344283           protein_coding      1
# 2344358           protein_coding      1
# 2344376  nonsense_mediated_decay      1
# 2360212           protein_coding      1
# 2417441           protein_coding      1
# 2417512           protein_coding      1
# 2417553           protein_coding      1
# 2417629           protein_coding      1
# 2417647           protein_coding      1
# 2440629           protein_coding      1
# 2440639           protein_coding      1
# 2440649           protein_coding      1
# 2440663           protein_coding      1
# 2481246           protein_coding      1
# 2551060           protein_coding      1
#
# [255 rows x 27 columns]

# %%
start_codons['seq'] = start_codons.apply(get_seq, axis=1)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-dfc73f270a25> in <module>()
# ----> 1 start_codons['seq'] = start_codons.apply(get_seq, axis=1)
#
# /home/cmb-panasas2/skchoudh/software_frozen/anaconda27/envs/riboraptor/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# /home/cmb-panasas2/skchoudh/software_frozen/anaconda27/envs/riboraptor/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# /home/cmb-panasas2/skchoudh/software_frozen/anaconda27/envs/riboraptor/lib/python3.6/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# /home/cmb-panasas2/skchoudh/software_frozen/anaconda27/envs/riboraptor/lib/python3.6/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-8-be2163e634cc> in get_seq(row)
#      96
#      97     if strand == '+':
# ---> 98         return fasta.get_seq(chrom, start, end)
#      99     else:
#     100         seq = fasta.get_seq(chrom, start, end)
#
# /home/cmb-panasas2/skchoudh/software_frozen/anaconda27/envs/riboraptor/lib/python3.6/site-packages/pyfaidx/__init__.py in get_seq(self, name, start, end, rc)
#    1013         """
#    1014         # Get sequence from real genome object and save result.
# -> 1015         seq = self.faidx.fetch(name, start, end)
#    1016         if rc:
#    1017             return -seq
#
# /home/cmb-panasas2/skchoudh/software_frozen/anaconda27/envs/riboraptor/lib/python3.6/site-packages/pyfaidx/__init__.py in fetch(self, name, start, end)
#     611             seq = self.from_buffer(start, end)
#     612         else:
# --> 613             seq = self.from_file(name, start, end)
#     614
#     615         return self.format_seq(seq, name, start, end)
#
# /home/cmb-panasas2/skchoudh/software_frozen/anaconda27/envs/riboraptor/lib/python3.6/site-packages/pyfaidx/__init__.py in from_file(self, rname, start, end, internals)
#     623         5. Read to end position, return sequence
#     624         """
# --> 625         assert start == int(start)
#     626         assert end == int(end)
#     627         try:
#
# AssertionError: occurred at index 56
